# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# Data quality was good, only 1 mouse out of 249 had duplicate timepoints neccesitating it's removal from the experiment.
#
# The Capomulin Regimen had a higher median finale tumor volume than the Remicane Regimen, however the Capomulin had a significantly lower interquartile range.
#
# In plotting the mouse weight vs. tumor volume there appeared to be a strong positive correlation between the two which is supported with an R-squared score above .7

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# Combine the data into a single dataset
mouse_study = pd.merge(mouse_metadata, study_results, on="Mouse ID")

# Display the data table for preview
mouse_study
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
#Counts the number of unique Mouse IDs
num_mice=mouse_study["Mouse ID"].nunique()
#Loads number into Dataframe
total_mice=pd.DataFrame({"Total Mice":[num_mice]})
total_mice.head()
# Out:
#    Total Mice
# 0         249

# %%
# Getting the Mouse ID numbers that show up with duplicate Timepoints. 
#uses .duplicated to find and isolate all duplicate Mouse ID/Timepoint pairs
dupe_mice=mouse_study[mouse_study.duplicated(['Mouse ID', 'Timepoint'], keep=False)]

# %%
# Optional: Display all the data for the duplicate mouse ID. 
dupe_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# ...

# %%
# Create a clean DataFrame by dropping all data associated with the duplicate mouse by its ID.

for mouse in dupe_mice['Mouse ID']:
    #iterates through all study  data and retains any IDs that do not show up in dupe_mice
    clean_mouse_study = mouse_study [mouse_study['Mouse ID'] != mouse]
clean_mouse_study
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
#Counts the number of unique Mouse IDs
num_mice_clean=clean_mouse_study["Mouse ID"].nunique()
#Loads number into Dataframe
total_mice_clean=pd.DataFrame({"Total Mice":[num_mice_clean]})
total_mice_clean.head()
# Out:
#    Total Mice
# 0         248

# %% [markdown]
# ## Summary Statistics

# %%
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
study_summary_df=pd.DataFrame()    
drug_group=clean_mouse_study.groupby("Drug Regimen")    
study_summary_df["Tumor Vol. Mean (mm3)"]=drug_group["Tumor Volume (mm3)"].mean()
study_summary_df["Tumor Vol. Median (mm3)"]=drug_group["Tumor Volume (mm3)"].median()
study_summary_df["Tumor Vol. Variance"]=drug_group["Tumor Volume (mm3)"].var()
study_summary_df["Tumor Vol. Std. Deviation"]=drug_group["Tumor Volume (mm3)"].std()
study_summary_df["Tumor Vol. SEM"]=drug_group["Tumor Volume (mm3)"].sem()
study_summary_df
# Out:
#               Tumor Vol. Mean (mm3)  Tumor Vol. Median (mm3)  \
# Drug Regimen
# Capomulin                 40.675741                41.557809
# Ceftamin                  52.591172                51.776157
# Infubinol                 52.884795                51.820584
# Ketapril                  55.235638                53.698743
# Naftisol                  54.331565                52.509285
# Placebo                   54.033581                52.288934
# Propriva                  52.320930                50.446266
# Ramicane                  40.216745                40.673236
# Stelasyn                  54.233149                52.431737
# Zoniferol                 53.236507                51.818479
#
#               Tumor Vol. Variance  Tumor Vol. Std. Deviation  Tumor Vol. SEM
# Drug Regimen
# Capomulin               24.947764                   4.994774        0.329346
# Ceftamin                39.290177                   6.268188        0.469821
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume
# for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
clean_mouse_study.groupby('Drug Regimen').agg({'Tumor Volume (mm3)': ['mean' , 'median', 'var', 'std', 'sem']})
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.

drug_and_time = clean_mouse_study.groupby('Drug Regimen').agg({'Timepoint': 'count'})
drug_and_time.plot(kind="bar", legend=False, title="Number of Measurements per Regimen", figsize=(15,7)).set(ylabel='Number of Measurements')
# Out:
# [Text(0, 0.5, 'Number of Measurements')]

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
x_axis=np.arange(len(study_summary_df))
tick_locations = [x for x in x_axis]
plt.figure(figsize=(15,7))
plt.bar(x_axis, drug_group["Drug Regimen"].count() )
plt.xticks(tick_locations, drug_group['Drug Regimen'].unique())
plt.ylabel("Number of Measurements")
# Out:
# Text(0, 0.5, 'Number of Measurements')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
m_v_f = clean_mouse_study.groupby('Sex').agg({'Mouse ID': 'nunique'})
m_v_f.plot(kind="pie", subplots=True, figsize=(6,6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002E4651EF070>],
#       dtype=object)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels='Female', 'Male'
sizes=m_v_f["Mouse ID"]
plt.pie(sizes, labels=labels,autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2e4690753a0>,
# ...
#  [Text(0.013934097579311265, 1.0999117423341975, 'Female'),
#   Text(-0.0139340975793114, -1.0999117423341975, 'Male')],
#  [Text(0.007600416861442507, 0.5999518594550168, '49.6%'),
#   Text(-0.007600416861442581, -0.5999518594550168, '50.4%')])

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
end_times=clean_mouse_study.sort_values('Timepoint', ascending=False).drop_duplicates(['Mouse ID'])
#This method of getting the last timepoint makes merging unnecessary, fount on Stack Overflow, user:Rani
#https://stackoverflow.com/questions/15705630/get-the-rows-which-have-the-max-value-in-groups-using-groupby

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for a for loop (and later for plot labels)
drug_list="Capomulin","Ramicane", "Infubinol", "Ceftamin"

#For loop iterates through drug list
for drug in drug_list:
    #locates rows with drug name in column and loads them into variable
    cap_data=end_times.loc[end_times["Drug Regimen"]==drug]
# Create empty list to fill with tumor vol data (for plotting)

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
    #Calculations are performed on loaded varible and results are printed out
    quartiles = cap_data['Tumor Volume (mm3)'].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    print(f"Quartiles for Tumor Volume on {drug} Regimen")
    print("-----------------------------------------------")
    print(f"The lower quartile of Tumor Volume is: {lowerq}")
    print(f"The upper quartile of Tumor Volume is: {upperq}")
    print(f"The interquartile range of Tumor Volume is: {iqr}")
    print(f"The the median of Tumor Volume is: {quartiles[0.5]} ")
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f"Values below {lower_bound} could be outliers.")
    print(f"Values above {upper_bound} could be outliers.")
    print("+++++++++++++++++++++++++++++++++++++++++++++++")
# Out:
# Quartiles for Tumor Volume on Capomulin Regimen
# -----------------------------------------------
# The lower quartile of Tumor Volume is: 32.37735684
# The upper quartile of Tumor Volume is: 40.1592203
# The interquartile range of Tumor Volume is: 7.781863460000004
# The the median of Tumor Volume is: 38.125164399999996
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.
# +++++++++++++++++++++++++++++++++++++++++++++++
# Quartiles for Tumor Volume on Ramicane Regimen
# -----------------------------------------------
# The lower quartile of Tumor Volume is: 31.56046955
# The upper quartile of Tumor Volume is: 40.65900627
# The interquartile range of Tumor Volume is: 9.098536719999998
# The the median of Tumor Volume is: 36.56165229
# Values below 17.912664470000003 could be outliers.
# Values above 54.30681135 could be outliers.
# +++++++++++++++++++++++++++++++++++++++++++++++
# Quartiles for Tumor Volume on Infubinol Regimen
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
#i variable used to change box position
i=1
#for loop revisited to iterate through different drug regimen
for drug in drug_list:
    cap_data=end_times.loc[end_times["Drug Regimen"]==drug]
    #Boxplot added to plt, position determined by i variable
    plt.boxplot(cap_data['Tumor Volume (mm3)'],positions = [i])
    #i variable itterated
    i=i+1
# Tick mark labels on x axis changed to drug names
plt.xticks([1, 2, 3, 4], ["Capomulin","Ramicane", "Infubinol", "Ceftamin"])
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
# Mouse ID g316 chosen as subject and all other mouse IDs removed
g316_data=clean_mouse_study.loc[clean_mouse_study["Mouse ID"]=="g316"]
#Line plot set up using timepoints and tumor volume, labels and title added for clarity
plt.plot(g316_data["Timepoint"], g316_data["Tumor Volume (mm3)"])
plt.title("Mouse g316 Tumor Volume over Time on Capomulin")
plt.ylabel("Tumor Volume (mm3)")
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
# All other drug regimen except Capomulin removed
Capomulin=clean_mouse_study.loc[clean_mouse_study["Drug Regimen"]=="Capomulin"]
# Data grouped my Mouse ID
Capomulin_mice=Capomulin.groupby("Mouse ID") 
# Average mouse weight and average tumor volume are loaded into axis variable Note:Mouse weight does not appear to change
x_values = Capomulin_mice['Weight (g)'].mean()
y_values = Capomulin_mice["Tumor Volume (mm3)"].mean()
#Scatter plot produced using variables
plt.scatter(x_values,y_values)
plt.xlabel('Weight of Mouse')
plt.ylabel('Average Tumor Volume')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
x_values = Capomulin_mice['Weight (g)'].mean()
y_values = Capomulin_mice["Tumor Volume (mm3)"].mean()
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(16,44),fontsize=15,color="red")
plt.xlabel('Weight of Mouse')
plt.ylabel('Average Tumor Volume')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7088568047708717
